# %% [markdown]
# <a href="https://colab.research.google.com/github/fqamar786/egocenters-template/blob/main/Yet_another_copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Why I Choose This data**:
#
# **Context:**
#
# This is a multivariate type of dataset which means providing or involving a variety of separate mathematical or statistical variables, multivariate numerical data analysis. It is composed of 14 attributes which are age, sex, chest pain type, resting blood pressure, serum cholesterol, fasting blood sugar, resting electrocardiographic results, maximum heart rate achieved, exercise-induced angina, oldpeak — ST depression induced by exercise relative to rest, the slope of the peak exercise ST segment, number of major vessels and Thalassemia. This database includes 76 attributes, but all published studies relate to the use of a subset of 14 of them. The Cleveland database is the only one used by ML researchers to date. One of the major tasks on this dataset is to predict based on the given attributes of a patient that whether that particular person has heart disease or not and other is the experimental task to diagnose and find out various insights from this dataset which could help in understanding the problem more.

# %% [markdown]
# ## Dataset Description:
#
# | Variable   | Description                                                                                   |
# |------------|-----------------------------------------------------------------------------------------------|
# | age        | Age of the patient in years                                                                   |
# | sex        | Gender of the patient (0 = male, 1 = female)                                                  |
# | cp         | Chest pain type: 0: Typical angina, 1: Atypical angina, 2: Non-anginal pain, 3: Asymptomatic |
# | trestbps   | Resting blood pressure in mm Hg                                                               |
# | chol       | Serum cholesterol in mg/dl                                                                    |
# | fbs        | Fasting blood sugar level, categorized as above 120 mg/dl (1 = true, 0 = false)               |
# | restecg    | Resting electrocardiographic results: 0: Normal, 1: Having ST-T wave abnormality, 2: Showing probable or definite left ventricular hypertrophy |
# | thalach    | Maximum heart rate achieved during a stress test                                              |
# | exang      | Exercise-induced angina (1 = yes, 0 = no)                                                     |
# | oldpeak    | ST depression induced by exercise relative to rest                                             |
# | slope      | Slope of the peak exercise ST segment: 0: Upsloping, 1: Flat, 2: Downsloping                   |
# | ca         | Number of major vessels (0-4) colored by fluoroscopy                                           |
# | thal       | Thalium stress test result: 0: Normal, 1: Fixed defect, 2: Reversible defect, 3: Not described |
# | target     | Heart disease status (0 = no disease, 1 = presence of disease)                                 |

# %%
# !pip install seaborn
# !pip install catboost
import seaborn as sns
import numpy as np
import pandas as pd
from typing import Any, List, Dict, Tuple
from google.colab import files

import tqdm
import matplotlib.pyplot as plt
from scipy.stats import pearsonr


from sklearn.base import BaseEstimator
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import roc_auc_score, roc_curve, f1_score, fbeta_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, log_loss
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

import seaborn as sns
sns.set(style="darkgrid")

from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %% [markdown]
# Next, I'll delve into a detailed exploration of the dataset:

# %%
data = pd.read_csv('/content/Heart_disease_cleveland_new.csv')

# %%
print('Shape of the data is ', data.shape)
data.head()
# Out:
# Shape of the data is  (303, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target
# 0   0     2       0
# 1   3     1       1
# 2   2     3       1
# 3   0     1       0
# 4   0     1       0

# %% [markdown]
# **##Data Info**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# **We need to check for missing data and see if there is an appropriate way to fill it in.**

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Since there is no missing entries in the data . So we can easily move forward.

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ## Distribution of Heart disease on the basis of target

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(10,5),facecolor=(.94, .94, .94))


ax1 = data['target'].value_counts().plot.pie( x ="Heart disease" ,y ='no.of patients',
                   autopct = "%1.0f%%",labels=["Normal","Heart Disease"], startangle = 60,ax=ax1,colors = sns.color_palette("crest"));
ax1.set(title = 'Percentage of Heart disease patients in Dataset')

ax2 = data["target"].value_counts().plot(kind="barh",ax =ax2)
for x,y in enumerate(data["target"].value_counts().values):
    ax2.text(.5,x,y,fontsize=12)
ax2.set(title = 'No. of Heart disease patients in Dataset')
plt.show()

# %% [markdown]
# ##  Gender and Agewise Distribution

# %%
plt.figure(figsize=(16,10))
plt.subplot(221)
data["sex"].value_counts().plot.pie(autopct = "%1.0f%%",colors = sns.color_palette("crest",5), startangle = 60,labels=["Male","Female"],
wedgeprops={"linewidth":2,"edgecolor":"k"},explode=[.1,.1],shadow =False)
plt.title("Distribution of Gender")
plt.subplot(222)
ax= sns.distplot(data['age'], rug=True)
plt.title("Age wise distribution")
plt.show()

# %%
data_1=data[data['target']==1]

data_0=data[data['target']==0]

# plotting normal patients
fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot2grid((1,2),(0,0))
sns.distplot(data_0['age'])
plt.title('AGE DISTRIBUTION OF NORMAL PATIENTS', fontsize=15, weight='bold')

ax1 = plt.subplot2grid((1,2),(0,1))
sns.countplot(x =data_0['sex'], palette='viridis')
plt.title('GENDER DISTRIBUTION OF NORMAL PATIENTS', fontsize=15, weight='bold' )
plt.show()

#plotting heart patients

fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot2grid((1,2),(0,0))
sns.distplot(data_1['age'])
plt.title('AGE DISTRIBUTION OF HEART DISEASE PATIENTS', fontsize=15, weight='bold')

ax1 = plt.subplot2grid((1,2),(0,1))
sns.countplot(x=data_1['sex'], palette='viridis')
plt.title('GENDER DISTRIBUTION OF HEART DISEASE PATIENTS', fontsize=15, weight='bold' )
plt.show()

# %% [markdown]
# ## Distribution of Chest Pain Type

# %%
# plotting normal patients
fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot2grid((1,2),(0,0))
sns.countplot(x =data_0['cp'],palette = 'ch:start=4.2,rot=-3.3')
plt.title('CHEST PAIN OF NORMAL PATIENTS', fontsize=15, weight='bold')

#plotting heart patients
ax1 = plt.subplot2grid((1,2),(0,1))
sns.countplot(x =data_1['cp'], palette='icefire')
plt.title('CHEST PAIN OF HEART PATIENTS', fontsize=15, weight='bold' )
plt.show()

# %%
plot_criteria= ['cp', 'target']
cm = sns.light_palette("green", as_cmap=True)
(round(pd.crosstab(data[plot_criteria[0]], data[plot_criteria[1]], normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style type="text/css">
# #T_e5d66_row0_col0, #T_e5d66_row0_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_e5d66_row1_col0 {
#   background-color: #79bc79;
#   color: #000000;
# }
# #T_e5d66_row1_col1 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_e5d66_row2_col0, #T_e5d66_row3_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_e5d66_row2_col1 {
#   background-color: #d1e6d1;
#   color: #000000;
# }
# #T_e5d66_row3_col0 {
#   background-color: #83c083;
#   color: #000000;
# }
# </style>
# <table id="T_e5d66" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th id="T_e5d66_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e5d66_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5d66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5d66_row0_col0" class="data row0 col0" >9.760000</td>
#       <td id="T_e5d66_row0_col1" class="data row0 col1" >5.040000</td>
#     </tr>
#     <tr>
#       <th id="T_e5d66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5d66_row1_col0" class="data row1 col0" >25.000000</td>
#       <td id="T_e5d66_row1_col1" class="data row1 col1" >6.470000</td>
#     </tr>
#     <tr>
#       <th id="T_e5d66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5d66_row2_col0" class="data row2 col0" >41.460000</td>
#       <td id="T_e5d66_row2_col1" class="data row2 col1" >12.950000</td>
#     </tr>
#     <tr>
#       <th id="T_e5d66_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5d66_row3_col0" class="data row3 col0" >23.780000</td>
#       <td id="T_e5d66_row3_col1" class="data row3 col1" >75.540000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# numerical fearures 6
num_feats = ['age', 'chol', 'restecg', 'thalach', 'oldpeak', 'ca']
# categorical (binary)
bin_feats = ['sex', 'fbs', 'exang', 'target']
# caterorical (multi-)
nom_feats= ['cp', 'restecg', 'slope', 'thal']
cat_feats = nom_feats + bin_feats

# %%
# Before the plotting loop, print the columns in your DataFrame:
print(data.columns)

# Check for any discrepancies with the 'cholesterol' column name.
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# ## Distribution of Numerical features

# %%
X = data.drop(['target'],axis=1)
y = data['target']

# %%
import math # Importing the math module

# Get the number of columns from the original DataFrame 'data'
num_columns = len(data.drop(['target'], axis=1).columns)
cols = 3  # Number of columns in the grid (adjust as needed)
rows = math.ceil(num_columns / cols)

# Create a grid of subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))  # Adjust figure size as needed
axes = axes.flatten()  # Flatten to easily iterate over axes

# Use data.drop(['target'], axis=1) instead of X for column iteration
for i, column in enumerate(data.drop(['target'], axis=1).columns):
    ax = axes[i]
    if data[column].dtype == 'object' or len(data[column].unique()) < 20:
        # For categorical or discrete features, use a bar plot
        data[column].value_counts().plot(kind='bar', ax=ax)
        ax.set_title(f'Distribution of {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')
    else:
        # For continuous features, use a histogram
        data[column].plot(kind='hist', bins=20, ax=ax)
        ax.set_title(f'Distribution of {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')

# Remove empty subplots if any
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()  # Adjust layout for readability
plt.show()

# %%
# Define your color palette here.
# Example using a seaborn palette:
mypal = sns.color_palette("Set2")
# Check for any discrepancies with the 'cholesterol' column name.
# If the column name is different, correct it in the 'num_feats' list.
# For example, if the actual column name is 'cholestrol', change it like this:
# num_feats = ['age', 'cholestrol', 'resting_blood_pressure', 'max_heart_rate_achieved', 'st_depression', 'num_major_vessels']

L = len(num_feats)
ncol= 2
nrow= int(np.ceil(L/ncol))
#remove_last= (nrow * ncol) - L

fig, ax = plt.subplots(nrow, ncol, figsize=(16, 14),facecolor='#F6F5F4')
fig.subplots_adjust(top=0.92)

i = 1
for col in num_feats:
    plt.subplot(nrow, ncol, i, facecolor='#F6F5F4')

    # Check if the column exists in the DataFrame before plotting
    if col in data.columns:
        ax = sns.kdeplot(data=data, x=col, hue="target", multiple="stack", palette=mypal[1::4])
        ax.set_xlabel(col, fontsize=20)
        ax.set_ylabel("density", fontsize=20)
        sns.despine(right=True)
        sns.despine(offset=0, trim=False)

        if col == 'num_major_vessels':
            sns.countplot(data=data, x=col, hue="target", palette=mypal[1::4])
            for p in ax.patches:
                    height = p.get_height()
                    ax.text(p.get_x()+p.get_width()/2.,height + 3,'{:1.0f}'.format((height)),ha="center",
                          bbox=dict(facecolor='none', edgecolor='black', boxstyle='round', linewidth=0.5))
    else:
        print(f"Column '{col}' not found in DataFrame. Skipping...")

    i = i +1
plt.suptitle('Distribution of Numerical Features' ,fontsize = 24);

# %% [markdown]
# ## Checking Correlation

# %%
# Now you can use corrwith
X.corrwith(pd.Series(y, index=X.index)).plot.bar(
    figsize=(12, 4), title="Correlation with Diabetes", fontsize=12,
    rot=90, grid=True)
# Out:
# <Axes: title={'center': 'Correlation with Diabetes'}>

# %%
# Split the data into training and test sets exactly as per your code
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=50)

# %%
X_binarized = pd.DataFrame(index=X.index)

# %% [markdown]
# 1. **Age (age)**
#
# Description: Age of the person in years, ranging from 29 to 79.
#
# Thresholds: We'll create age groups based on common age ranges:
#
# Under 40
# 40-50
# 50-60
# 60-70
# Over 70

# %%
# Calculate minimum and maximum age from the training data
min_age = X_train['age'].min()
max_age = X_train['age'].max()
min_age, max_age
# Out:
# (29, 77)

# %%
# Define thresholds exactly as per your code
thresholds = [min_age, 40,50, 60, max_age]

# %%
# Binarize age based on thresholds using your code
for threshold in thresholds:
    X_binarized[f'age_le_{threshold}'] = X['age'] <= threshold
    X_binarized[f'age_ge_{threshold}'] = X['age'] >= threshold

# %% [markdown]
# 2. Sex (sex)
# Description:
# 1: Male
# 0: Female

# %%
X_binarized['male'] = X['sex'] == 1

# %% [markdown]
# 3. Chest Pain Type (cp)
# Description: Chest pain type with values ranging from 0 to 3.
#
# 0: Typical Angina
# 1: Atypical Angina
# 2: Non-Anginal Pain
# 3: Asymptomatic

# %%
X_binarized['cp_typical_angina'] = X['cp'] == 0
X_binarized['cp_atypical_angina'] = X['cp'] == 1
X_binarized['cp_non_anginal_pain'] = X['cp'] == 2
X_binarized['cp_asymptomatic'] = X['cp'] == 3

# Alternatively, you can group certain types together if needed
X_binarized['cp_angina'] = X['cp'].isin([0, 1])  # Typical and Atypical Angina
X_binarized['cp_non_angina'] = X['cp'].isin([2, 3])  # Non-Anginal Pain and Asymptomatic

# %% [markdown]
# 4. Resting Blood Pressure (trestbps)
# Description: Resting blood pressure in mm Hg.
#
# Processing:
#
# Use thresholds based on the distribution in the training data or standard medical categories.
# Binarize based on these thresholds.

# %%
# Get minimum and maximum values from training data
min_trestbps = X_train['trestbps'].min()
max_trestbps = X_train['trestbps'].max()
min_trestbps , max_trestbps
# Out:
# (94, 200)

# %%
# Define thresholds (you can adjust these thresholds based on your data)
thresholds = [min_trestbps, 120, 140, 160, max_trestbps]

# %%
# Binarize trestbps based on thresholds
for threshold in thresholds:
    X_binarized[f'trestbps_le_{threshold}'] = X['trestbps'] <= threshold
    X_binarized[f'trestbps_ge_{threshold}'] = X['trestbps'] >= threshold

# %% [markdown]
# 5. Serum Cholesterol (chol)
# Description: Serum cholesterol in mg/dl.
#
# Processing:
#
# Use thresholds based on medical guidelines or data distribution.
# Binarize based on these thresholds.

# %%
# Get minimum and maximum values from training data
min_chol = X_train['chol'].min()
max_chol = X_train['chol'].max()
min_chol , max_chol
# Out:
# (131, 417)

# %%
# Define thresholds
thresholds = [min_chol, 200, 240, max_chol]

# %%
# Binarize chol based on thresholds
for threshold in thresholds:
    X_binarized[f'chol_le_{threshold}'] = X['chol'] <= threshold
    X_binarized[f'chol_ge_{threshold}'] = X['chol'] >= threshold

# %% [markdown]
# 6. **Fasting Blood Sugar (fbs)**
#
# Description:
#
# 0: Fasting blood sugar less than or equal to 120 mg/dl
#
# 1: Fasting blood sugar greater than 120 mg/dl

# %%
X_binarized['fbs_high'] = X['fbs'] == 1
X_binarized['fbs_normal'] = X['fbs'] == 0

# %% [markdown]
# 7. Resting Electrocardiographic Results (restecg)
# Description:
#
# 0: Normal
# 1: ST-T wave abnormality
# 2: Left ventricular hypertrophy

# %%
X_binarized['restecg_normal'] = X['restecg'] == 0
X_binarized['restecg_stt_abnormality'] = X['restecg'] == 1
X_binarized['restecg_lv_hypertrophy'] = X['restecg'] == 2

# %% [markdown]
# 8. Maximum Heart Rate Achieved (thalach)
#
# Description: Maximum heart rate achieved.

# %%
# Get minimum and maximum values from training data
min_thalach = X_train['thalach'].min()
max_thalach = X_train['thalach'].max()
min_thalach , max_thalach
# Out:
# (71, 202)

# %%
# Define thresholds
thresholds = [min_thalach, 100, 150, max_thalach]

# %%
# Binarize thalach based on thresholds
for threshold in thresholds:
    X_binarized[f'thalach_le_{threshold}'] = X['thalach'] <= threshold
    X_binarized[f'thalach_ge_{threshold}'] = X['thalach'] >= threshold

# %% [markdown]
# 9.** Exercise-Induced Angina (exang)**
# Description:
#
# 0: No
#
# 1: Yes

# %%
X_binarized['exang'] = X['exang'] == 1
X_binarized['no_exang'] = X['exang'] == 0

# %% [markdown]
# 10. ST Depression Induced by Exercise (oldpeak)
# Description: ST depression induced by exercise relative to rest.

# %%
# Get minimum and maximum values from training data
min_oldpeak = X_train['oldpeak'].min()
max_oldpeak = X_train['oldpeak'].max()
min_oldpeak , max_oldpeak
# Out:
# (0.0, 6.2)

# %%
# Define thresholds
thresholds = [min_oldpeak, 1.0, 2.0, max_oldpeak]

# %%
# Binarize oldpeak based on thresholds
for threshold in thresholds:
    X_binarized[f'oldpeak_le_{threshold}'] = X['oldpeak'] <= threshold
    X_binarized[f'oldpeak_ge_{threshold}'] = X['oldpeak'] >= threshold

# %% [markdown]
# 11.** Slope of Peak Exercise ST Segment (slope)**
#
# Description:
#
# 1: Upsloping
#
# 2: Flat
#
# 3: Downsloping

# %%
X_binarized['slope_upsloping'] = X['slope'] == 1
X_binarized['slope_flat'] = X['slope'] == 2
X_binarized['slope_downsloping'] = X['slope'] == 3

# %% [markdown]
# 12. Number of Major Vessels Colored by Fluoroscopy (ca)
#
# Description: Number of major vessels (0-3) colored by fluoroscopy.

# %%
for value in sorted(X['ca'].unique()):
    X_binarized[f'ca_{value}'] = X['ca'] == value

# %% [markdown]
# 13**. Thalassemia (thal)**
#
# Description:
#
# 1: Normal
#
# 2: Fixed defect
#
# 3: Reversible defect
#
# 0 or missing: Unknown or null

# %%
# Replace 0 with NaN for missing values
X['thal'] = X['thal'].replace(0, np.nan)

X_binarized['thal_normal'] = X['thal'] == 1
X_binarized['thal_fixed_defect'] = X['thal'] == 2
X_binarized['thal_reversible_defect'] = X['thal'] == 3
X_binarized['thal_missing'] = X['thal'].isna()

# %%
X_binarized = X_binarized.astype(int)

# %%
X_binarized.shape
# Out:
# (303, 69)

# %%
# Frequency counts for each binarized variable
for column in X_binarized.columns:
    print(f"Value counts for {column}:")
    print(X_binarized[column].value_counts())
    print("\n")
# Out:
# Value counts for age_le_29:
# age_le_29
# 0    302
# 1      1
# Name: count, dtype: int64
#
#
# Value counts for age_ge_29:
# age_ge_29
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for age_le_40:
# age_le_40
# 0    285
# 1     18
# Name: count, dtype: int64
#
#
# Value counts for age_ge_40:
# age_ge_40
# 1    288
# 0     15
# Name: count, dtype: int64
#
#
# Value counts for age_le_50:
# age_le_50
# 0    209
# 1     94
# Name: count, dtype: int64
#
#
# Value counts for age_ge_50:
# age_ge_50
# 1    216
# 0     87
# Name: count, dtype: int64
#
#
# Value counts for age_le_60:
# age_le_60
# 1    224
# 0     79
# Name: count, dtype: int64
#
#
# Value counts for age_ge_60:
# age_ge_60
# 0    212
# 1     91
# Name: count, dtype: int64
#
#
# Value counts for age_le_77:
# age_le_77
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for age_ge_77:
# age_ge_77
# 0    302
# 1      1
# Name: count, dtype: int64
#
#
# Value counts for male:
# male
# 1    206
# 0     97
# Name: count, dtype: int64
#
#
# Value counts for cp_typical_angina:
# cp_typical_angina
# 0    280
# 1     23
# Name: count, dtype: int64
#
#
# Value counts for cp_atypical_angina:
# cp_atypical_angina
# 0    253
# 1     50
# Name: count, dtype: int64
#
#
# Value counts for cp_non_anginal_pain:
# cp_non_anginal_pain
# 0    217
# 1     86
# Name: count, dtype: int64
#
#
# Value counts for cp_asymptomatic:
# cp_asymptomatic
# 0    159
# 1    144
# Name: count, dtype: int64
#
#
# Value counts for cp_angina:
# cp_angina
# 0    230
# 1     73
# Name: count, dtype: int64
#
#
# Value counts for cp_non_angina:
# cp_non_angina
# 1    230
# 0     73
# Name: count, dtype: int64
#
#
# Value counts for trestbps_le_94:
# trestbps_le_94
# 0    301
# 1      2
# Name: count, dtype: int64
#
#
# Value counts for trestbps_ge_94:
# trestbps_ge_94
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for trestbps_le_120:
# trestbps_le_120
# 0    206
# 1     97
# Name: count, dtype: int64
#
#
# Value counts for trestbps_ge_120:
# trestbps_ge_120
# 1    243
# 0     60
# Name: count, dtype: int64
#
#
# Value counts for trestbps_le_140:
# trestbps_le_140
# 1    237
# 0     66
# Name: count, dtype: int64
#
#
# Value counts for trestbps_ge_140:
# trestbps_ge_140
# 0    205
# 1     98
# Name: count, dtype: int64
#
#
# Value counts for trestbps_le_160:
# trestbps_le_160
# 1    288
# 0     15
# Name: count, dtype: int64
#
#
# Value counts for trestbps_ge_160:
# trestbps_ge_160
# 0    277
# 1     26
# Name: count, dtype: int64
#
#
# Value counts for trestbps_le_200:
# trestbps_le_200
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for trestbps_ge_200:
# trestbps_ge_200
# 0    302
# 1      1
# Name: count, dtype: int64
#
#
# Value counts for chol_le_131:
# chol_le_131
# 0    301
# 1      2
# Name: count, dtype: int64
#
#
# Value counts for chol_ge_131:
# chol_ge_131
# 1    302
# 0      1
# Name: count, dtype: int64
#
#
# Value counts for chol_le_200:
# chol_le_200
# 0    253
# 1     50
# Name: count, dtype: int64
#
#
# Value counts for chol_ge_200:
# chol_ge_200
# 1    254
# 0     49
# Name: count, dtype: int64
#
#
# Value counts for chol_le_240:
# chol_le_240
# 0    152
# 1    151
# Name: count, dtype: int64
#
#
# Value counts for chol_ge_240:
# chol_ge_240
# 1    156
# 0    147
# Name: count, dtype: int64
#
#
# Value counts for chol_le_417:
# chol_le_417
# 1    302
# 0      1
# Name: count, dtype: int64
#
#
# Value counts for chol_ge_417:
# chol_ge_417
# 0    301
# 1      2
# Name: count, dtype: int64
#
#
# Value counts for fbs_high:
# fbs_high
# 0    258
# 1     45
# Name: count, dtype: int64
#
#
# Value counts for fbs_normal:
# fbs_normal
# 1    258
# 0     45
# Name: count, dtype: int64
#
#
# Value counts for restecg_normal:
# restecg_normal
# 0    152
# 1    151
# Name: count, dtype: int64
#
#
# Value counts for restecg_stt_abnormality:
# restecg_stt_abnormality
# 0    299
# 1      4
# Name: count, dtype: int64
#
#
# Value counts for restecg_lv_hypertrophy:
# restecg_lv_hypertrophy
# 0    155
# 1    148
# Name: count, dtype: int64
#
#
# Value counts for thalach_le_71:
# thalach_le_71
# 0    302
# 1      1
# Name: count, dtype: int64
#
#
# Value counts for thalach_ge_71:
# thalach_ge_71
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for thalach_le_100:
# thalach_le_100
# 0    295
# 1      8
# Name: count, dtype: int64
#
#
# Value counts for thalach_ge_100:
# thalach_ge_100
# 1    295
# 0      8
# Name: count, dtype: int64
#
#
# Value counts for thalach_le_150:
# thalach_le_150
# 0    164
# 1    139
# Name: count, dtype: int64
#
#
# Value counts for thalach_ge_150:
# thalach_ge_150
# 1    171
# 0    132
# Name: count, dtype: int64
#
#
# Value counts for thalach_le_202:
# thalach_le_202
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for thalach_ge_202:
# thalach_ge_202
# 0    302
# 1      1
# Name: count, dtype: int64
#
#
# Value counts for exang:
# exang
# 0    204
# 1     99
# Name: count, dtype: int64
#
#
# Value counts for no_exang:
# no_exang
# 1    204
# 0     99
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_le_0.0:
# oldpeak_le_0.0
# 0    204
# 1     99
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_ge_0.0:
# oldpeak_ge_0.0
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_le_1.0:
# oldpeak_le_1.0
# 1    180
# 0    123
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_ge_1.0:
# oldpeak_ge_1.0
# 0    166
# 1    137
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_le_2.0:
# oldpeak_le_2.0
# 1    253
# 0     50
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_ge_2.0:
# oldpeak_ge_2.0
# 0    244
# 1     59
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_le_6.2:
# oldpeak_le_6.2
# 1    303
# Name: count, dtype: int64
#
#
# Value counts for oldpeak_ge_6.2:
# oldpeak_ge_6.2
# 0    302
# 1      1
# Name: count, dtype: int64
#
#
# Value counts for slope_upsloping:
# slope_upsloping
# 0    163
# 1    140
# Name: count, dtype: int64
#
#
# Value counts for slope_flat:
# slope_flat
# 0    282
# 1     21
# Name: count, dtype: int64
#
#
# Value counts for slope_downsloping:
# slope_downsloping
# 0    303
# Name: count, dtype: int64
#
#
# Value counts for ca_0:
# ca_0
# 1    180
# 0    123
# Name: count, dtype: int64
#
#
# Value counts for ca_1:
# ca_1
# 0    238
# 1     65
# Name: count, dtype: int64
#
#
# Value counts for ca_2:
# ca_2
# 0    265
# 1     38
# Name: count, dtype: int64
#
#
# Value counts for ca_3:
# ca_3
# 0    283
# 1     20
# Name: count, dtype: int64
#
#
# Value counts for thal_normal:
# thal_normal
# 1    168
# 0    135
# Name: count, dtype: int64
#
#
# Value counts for thal_fixed_defect:
# thal_fixed_defect
# 0    285
# 1     18
# Name: count, dtype: int64
#
#
# Value counts for thal_reversible_defect:
# thal_reversible_defect
# 0    186
# 1    117
# Name: count, dtype: int64
#
#
# Value counts for thal_missing:
# thal_missing
# 0    303
# Name: count, dtype: int64

# %%
# Combine binarized features with the target variable
data_binarized = pd.concat([X_binarized, y.reset_index(drop=True)], axis=1)

# Display the first few rows with replacements
print(data_binarized.head().replace({1: 'x', 0: ''}))
# Out:
#   age_le_29 age_ge_29 age_le_40 age_ge_40 age_le_50 age_ge_50 age_le_60  \
# 0                   x                   x                   x
# 1                   x                   x                   x
# 2                   x                   x                   x
# 3                   x         x                   x                   x
# 4                   x                   x         x                   x
#
#   age_ge_60 age_le_77 age_ge_77  ... slope_downsloping ca_0 ca_1 ca_2 ca_3  \
# 0         x         x            ...                      x
# 1         x         x            ...                                     x
# 2         x         x            ...                                x
# 3                   x            ...                      x
# 4                   x            ...                      x
#
#   thal_normal thal_fixed_defect thal_reversible_defect thal_missing target
# 0                             x
# 1           x                                                            x
# 2                                                    x                   x
# 3           x
# 4           x
#
# [5 rows x 70 columns]

# %%
data_binarized.shape
# Out:
# (303, 70)

# %%
data_binarized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 70 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age_le_29                303 non-null    int64
#  1   age_ge_29                303 non-null    int64
#  2   age_le_40                303 non-null    int64
#  3   age_ge_40                303 non-null    int64
#  4   age_le_50                303 non-null    int64
#  5   age_ge_50                303 non-null    int64
#  6   age_le_60                303 non-null    int64
#  7   age_ge_60                303 non-null    int64
#  8   age_le_77                303 non-null    int64
#  9   age_ge_77                303 non-null    int64
#  10  male                     303 non-null    int64
#  11  cp_typical_angina        303 non-null    int64
#  12  cp_atypical_angina       303 non-null    int64
#  13  cp_non_anginal_pain      303 non-null    int64
#  14  cp_asymptomatic          303 non-null    int64
#  15  cp_angina                303 non-null    int64
#  16  cp_non_angina            303 non-null    int64
#  17  trestbps_le_94           303 non-null    int64
#  18  trestbps_ge_94           303 non-null    int64
#  19  trestbps_le_120          303 non-null    int64
#  20  trestbps_ge_120          303 non-null    int64
#  21  trestbps_le_140          303 non-null    int64
#  22  trestbps_ge_140          303 non-null    int64
#  23  trestbps_le_160          303 non-null    int64
#  24  trestbps_ge_160          303 non-null    int64
#  25  trestbps_le_200          303 non-null    int64
#  26  trestbps_ge_200          303 non-null    int64
#  27  chol_le_131              303 non-null    int64
#  28  chol_ge_131              303 non-null    int64
#  29  chol_le_200              303 non-null    int64
#  30  chol_ge_200              303 non-null    int64
#  31  chol_le_240              303 non-null    int64
#  32  chol_ge_240              303 non-null    int64
#  33  chol_le_417              303 non-null    int64
#  34  chol_ge_417              303 non-null    int64
#  35  fbs_high                 303 non-null    int64
#  36  fbs_normal               303 non-null    int64
#  37  restecg_normal           303 non-null    int64
#  38  restecg_stt_abnormality  303 non-null    int64
#  39  restecg_lv_hypertrophy   303 non-null    int64
#  40  thalach_le_71            303 non-null    int64
#  41  thalach_ge_71            303 non-null    int64
#  42  thalach_le_100           303 non-null    int64
#  43  thalach_ge_100           303 non-null    int64
#  44  thalach_le_150           303 non-null    int64
#  45  thalach_ge_150           303 non-null    int64
#  46  thalach_le_202           303 non-null    int64
#  47  thalach_ge_202           303 non-null    int64
#  48  exang                    303 non-null    int64
#  49  no_exang                 303 non-null    int64
#  50  oldpeak_le_0.0           303 non-null    int64
#  51  oldpeak_ge_0.0           303 non-null    int64
#  52  oldpeak_le_1.0           303 non-null    int64
#  53  oldpeak_ge_1.0           303 non-null    int64
#  54  oldpeak_le_2.0           303 non-null    int64
#  55  oldpeak_ge_2.0           303 non-null    int64
#  56  oldpeak_le_6.2           303 non-null    int64
#  57  oldpeak_ge_6.2           303 non-null    int64
#  58  slope_upsloping          303 non-null    int64
#  59  slope_flat               303 non-null    int64
#  60  slope_downsloping        303 non-null    int64
#  61  ca_0                     303 non-null    int64
#  62  ca_1                     303 non-null    int64
#  63  ca_2                     303 non-null    int64
#  64  ca_3                     303 non-null    int64
#  65  thal_normal              303 non-null    int64
#  66  thal_fixed_defect        303 non-null    int64
#  67  thal_reversible_defect   303 non-null    int64
#  68  thal_missing             303 non-null    int64
#  69  target                   303 non-null    int64
# dtypes: int64(70)
# memory usage: 165.8 KB

# %%
X_binarized.head().replace({1: 'x', 0: ''})
# Out:
#   age_le_29 age_ge_29 age_le_40 age_ge_40 age_le_50 age_ge_50 age_le_60  \
# 0                   x                   x                   x
# 1                   x                   x                   x
# 2                   x                   x                   x
# 3                   x         x                   x                   x
# 4                   x                   x         x                   x
#
#   age_ge_60 age_le_77 age_ge_77  ... slope_flat slope_downsloping ca_0 ca_1  \
# 0         x         x            ...          x                      x
# 1         x         x            ...
# 2         x         x            ...
# 3                   x            ...          x                      x
# 4                   x            ...                                 x
#
#   ca_2 ca_3 thal_normal thal_fixed_defect thal_reversible_defect thal_missing
# 0                                       x
# 1         x           x
# 2    x                                                         x
# 3                     x
# 4                     x
#
# [5 rows x 69 columns]

# %% [markdown]
# Let's split the dataset:

# %%
X_train, X_test, y_train, y_test = train_test_split(X_binarized, y, test_size=0.2, stratify=y, random_state=42)

# %%
class LazyClassifierFCA:
    def __init__(self, max_counter_examples=0, min_cardinality=1):
        self.X_train_positive = None
        self.X_train_negative = None
        self.max_counter_examples = max_counter_examples
        self.min_cardinality = min_cardinality

    def fit(self, X_train, y_train):
        self.X_train_positive = X_train[y_train == 1].reset_index(drop=True)
        self.X_train_negative = X_train[y_train == 0].reset_index(drop=True)

    def classify_sample(self, sample, sample_index=None):
        sample_bool = sample.astype(bool)
        positive_votes = 0
        negative_votes = 0

        # For each positive object in C+
        for _, g_plus in self.X_train_positive.iterrows():
            intersection = sample_bool & g_plus.astype(bool)
            cardinality = intersection.sum()

            if cardinality < self.min_cardinality:
                continue

            # Check if intersection is present in any negative example
            counter_examples = self.X_train_negative[
                (self.X_train_negative & intersection).eq(intersection).all(axis=1)
            ]

            if len(counter_examples) <= self.max_counter_examples:
                positive_votes += 1

        # For each negative object in C-
        for _, g_minus in self.X_train_negative.iterrows():
            intersection = sample_bool & g_minus.astype(bool)
            cardinality = intersection.sum()

            if cardinality < self.min_cardinality:
                continue

            # Check if intersection is present in any positive example
            counter_examples = self.X_train_positive[
                (self.X_train_positive & intersection).eq(intersection).all(axis=1)
            ]

            if len(counter_examples) <= self.max_counter_examples:
                negative_votes += 1

        # Classify based on votes
        if positive_votes > negative_votes:
            prediction = 1
        elif negative_votes > positive_votes:
            prediction = 0
        else:
            prediction = 1  # Default to positive class

        # Debugging output
        if sample_index is not None:
            print(
                f"Sample {sample_index} is classified as {prediction}, "
                f"positive_votes={positive_votes}, negative_votes={negative_votes}"
            )

        return prediction

    def predict(self, X_test):
        return np.array([
            self.classify_sample(sample, sample_index=index)
            for index, sample in X_test.iterrows()
        ])

# %%
print(y)
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    1
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
len(X_train[y_train == 1]), len(X_train[y_train == 0])
# Out:
# (111, 131)

# %%
pos_X_train = X_train[y_train == 1]
neg_X_train = X_train[y_train == 0]
len(pos_X_train), len(neg_X_train)
# Out:
# (111, 131)

# %%
# Apply the LazyClassifierFCA
classifier_fca = LazyClassifierFCA(max_counter_examples=0, min_cardinality=1)
classifier_fca.fit(X_train, y_train)
y_pred_fca = classifier_fca.predict(X_test)
# Out:
# Sample 219 is classified as 0, positive_votes=17, negative_votes=80
# Sample 271 is classified as 1, positive_votes=72, negative_votes=35
# Sample 89 is classified as 0, positive_votes=1, negative_votes=89
# Sample 101 is classified as 0, positive_votes=19, negative_votes=80
# Sample 67 is classified as 1, positive_votes=79, negative_votes=72
# Sample 244 is classified as 0, positive_votes=38, negative_votes=108
# Sample 185 is classified as 0, positive_votes=14, negative_votes=66
# Sample 233 is classified as 0, positive_votes=53, negative_votes=60
# Sample 168 is classified as 1, positive_votes=57, negative_votes=52
# Sample 197 is classified as 0, positive_votes=22, negative_votes=92
# Sample 137 is classified as 1, positive_votes=82, negative_votes=37
# Sample 21 is classified as 0, positive_votes=23, negative_votes=57
# Sample 302 is classified as 0, positive_votes=4, negative_votes=88
# Sample 187 is classified as 1, positive_votes=55, negative_votes=52
# Sample 64 is classified as 1, positive_votes=92, negative_votes=60
# Sample 296 is classified as 1, positive_votes=84, negative_votes=39
# Sample 23 is classified as 1, positive_votes=75, negative_votes=15
# Sample 196 is classified as 1, positive_votes=60, negative_votes=52
# Sample 6 is classified as 1, positive_votes=41, negative_votes=37
# Sample 300 is classified as 1, positive_votes=91, negative_votes=23
# Sample 33 is classified as 0, positive_votes=67, negative_votes=86
# Sample 269 is classified as 0, positive_votes=26, negative_votes=102
# Sample 113 is classified as 1, positive_votes=85, negative_votes=11
# Sample 179 is classified as 0, positive_votes=23, negative_votes=79
# Sample 231 is classified as 1, positive_votes=73, negative_votes=38
# Sample 277 is classified as 0, positive_votes=4, negative_votes=99
# Sample 234 is classified as 0, positive_votes=37, negative_votes=69
# Sample 104 is classified as 1, positive_votes=83, negative_votes=63
# Sample 3 is classified as 0, positive_votes=44, negative_votes=82
# Sample 264 is classified as 1, positive_votes=88, negative_votes=46
# Sample 115 is classified as 0, positive_votes=45, negative_votes=93
# Sample 286 is classified as 1, positive_votes=80, negative_votes=8
# Sample 292 is classified as 1, positive_votes=69, negative_votes=36
# Sample 287 is classified as 0, positive_votes=49, negative_votes=71
# Sample 100 is classified as 0, positive_votes=18, negative_votes=45
# Sample 157 is classified as 1, positive_votes=68, negative_votes=53
# Sample 212 is classified as 0, positive_votes=62, negative_votes=105
# Sample 66 is classified as 0, positive_votes=76, negative_votes=103
# Sample 166 is classified as 0, positive_votes=16, negative_votes=95
# Sample 284 is classified as 1, positive_votes=64, negative_votes=33
# Sample 92 is classified as 1, positive_votes=80, negative_votes=34
# Sample 62 is classified as 1, positive_votes=87, negative_votes=1
# Sample 235 is classified as 1, positive_votes=83, negative_votes=52
# Sample 213 is classified as 1, positive_votes=88, negative_votes=37
# Sample 160 is classified as 0, positive_votes=15, negative_votes=54
# Sample 87 is classified as 0, positive_votes=21, negative_votes=106
# Sample 282 is classified as 1, positive_votes=89, negative_votes=13
# Sample 162 is classified as 0, positive_votes=0, negative_votes=94
# Sample 205 is classified as 1, positive_votes=77, negative_votes=26
# Sample 186 is classified as 0, positive_votes=54, negative_votes=88
# Sample 134 is classified as 0, positive_votes=0, negative_votes=100
# Sample 76 is classified as 1, positive_votes=96, negative_votes=0
# Sample 131 is classified as 1, positive_votes=39, negative_votes=37
# Sample 34 is classified as 0, positive_votes=18, negative_votes=89
# Sample 172 is classified as 0, positive_votes=70, negative_votes=80
# Sample 270 is classified as 1, positive_votes=94, negative_votes=28
# Sample 285 is classified as 1, positive_votes=67, negative_votes=31
# Sample 243 is classified as 1, positive_votes=65, negative_votes=56
# Sample 94 is classified as 0, positive_votes=5, negative_votes=21
# Sample 291 is classified as 0, positive_votes=0, negative_votes=56
# Sample 155 is classified as 1, positive_votes=76, negative_votes=50

# %%
def calculate_metrics(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Calculate metrics
    tnr = tn / (tn + fp) if (tn + fp) else 0
    npv = tn / (tn + fn) if (tn + fn) else 0
    fpr = fp / (fp + tn) if (fp + tn) else 0
    fdr = fp / (fp + tp) if (fp + tp) else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) else 0
    precision = tp / (tp + fp) if (tp + fp) else 0
    recall = tp / (tp + fn) if (tp + fn) else 0  # True Positive Rate
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) else 0

    metrics = {
        'True Positive': tp,
        'True Negative': tn,
        'False Positive': fp,
        'False Negative': fn,
        'True Negative Rate (Specificity)': tnr,
        'Negative Predictive Value': npv,
        'False Positive Rate': fpr,
        'False Discovery Rate': fdr,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall (True Positive Rate)': recall,
        'F1 Score': f1
    }

    return metrics

# %%
metrics_fca = calculate_metrics(y_test, y_pred_fca)

# Print the metrics
for metric, value in metrics_fca.items():
    print(f"{metric}: {value:.4f}")
# Out:
# True Positive: 26.0000
# True Negative: 28.0000
# False Positive: 5.0000
# False Negative: 2.0000
# True Negative Rate (Specificity): 0.8485
# Negative Predictive Value: 0.9333
# False Positive Rate: 0.1515
# False Discovery Rate: 0.1613
# Accuracy: 0.8852
# Precision: 0.8387
# Recall (True Positive Rate): 0.9286
# F1 Score: 0.8814

# %%
# 7. Apply standard classifiers
# Split data using original features
X_train_orig, X_test_orig, y_train_orig, y_test_orig = train_test_split(X_binarized, y, test_size=0.2, stratify=y, random_state=35)

# %%
# a. KNN
knn = KNeighborsClassifier()
knn.fit(X_train_orig, y_train_orig)
y_pred_knn = knn.predict(X_test_orig)
metrics_knn = calculate_metrics(y_test_orig, y_pred_knn)

# %%
# b. Naive Bayes
nb = GaussianNB()
nb.fit(X_train_orig, y_train_orig)
y_pred_nb = nb.predict(X_test_orig)
metrics_nb = calculate_metrics(y_test_orig, y_pred_nb)

# %%
# c. Logistic Regression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_orig, y_train_orig)
y_pred_lr = lr.predict(X_test_orig)
metrics_lr = calculate_metrics(y_test_orig, y_pred_lr)

# %%
# d. SVM
svm = SVC(probability=True)
svm.fit(X_train_orig, y_train_orig)
y_pred_svm = svm.predict(X_test_orig)
metrics_svm = calculate_metrics(y_test_orig, y_pred_svm)

# %%
# e. Decision Tree
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train_orig, y_train_orig)
y_pred_dt = dt.predict(X_test_orig)
metrics_dt = calculate_metrics(y_test_orig, y_pred_dt)

# %%
# f. Random Forest
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train_orig, y_train_orig)
y_pred_rf = rf.predict(X_test_orig)
metrics_rf = calculate_metrics(y_test_orig, y_pred_rf)

# %%
# g. XGBoost
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb.fit(X_train_orig, y_train_orig)
y_pred_xgb = xgb.predict(X_test_orig)
metrics_xgb = calculate_metrics(y_test_orig, y_pred_xgb)

# %%
# 8. Compile and compare results
classifiers = {
    'LazyClassifierFCA': metrics_fca,
    'KNN': metrics_knn,
    'Naive Bayes': metrics_nb,
    'Logistic Regression': metrics_lr,
    'SVM': metrics_svm,
    'Decision Tree': metrics_dt,
    'Random Forest': metrics_rf,
    'XGBoost': metrics_xgb
}

metrics_data = pd.DataFrame(classifiers).T

# %%
# 9. Display the results
print("Classification Metrics Comparison:\n")
print(metrics_data)
# Out:
# Classification Metrics Comparison:
#
#                      True Positive  True Negative  False Positive  \
# LazyClassifierFCA             26.0           28.0             5.0
# KNN                           21.0           32.0             1.0
# Naive Bayes                   21.0           29.0             4.0
# Logistic Regression           22.0           30.0             3.0
# SVM                           22.0           32.0             1.0
# Decision Tree                 21.0           26.0             7.0
# Random Forest                 21.0           29.0             4.0
# XGBoost                       21.0           29.0             4.0
#
#                      False Negative  True Negative Rate (Specificity)  \
# LazyClassifierFCA               2.0                          0.848485
# KNN                             7.0                          0.969697
# Naive Bayes                     7.0                          0.878788
# Logistic Regression             6.0                          0.909091
# SVM                             6.0                          0.969697
# Decision Tree                   7.0                          0.787879
# Random Forest                   7.0                          0.878788
# XGBoost                         7.0                          0.878788
#
#                      Negative Predictive Value  False Positive Rate  \
# LazyClassifierFCA                     0.933333             0.151515
# KNN                                   0.820513             0.030303
# Naive Bayes                           0.805556             0.121212
# Logistic Regression                   0.833333             0.090909
# SVM                                   0.842105             0.030303
# Decision Tree                         0.787879             0.212121
# Random Forest                         0.805556             0.121212
# XGBoost                               0.805556             0.121212
#
#                      False Discovery Rate  Accuracy  Precision  \
# LazyClassifierFCA                0.161290  0.885246   0.838710
# KNN                              0.045455  0.868852   0.954545
# Naive Bayes                      0.160000  0.819672   0.840000
# Logistic Regression              0.120000  0.852459   0.880000
# SVM                              0.043478  0.885246   0.956522
# Decision Tree                    0.250000  0.770492   0.750000
# Random Forest                    0.160000  0.819672   0.840000
# XGBoost                          0.160000  0.819672   0.840000
#
#                      Recall (True Positive Rate)  F1 Score
# LazyClassifierFCA                       0.928571  0.881356
# KNN                                     0.750000  0.840000
# Naive Bayes                             0.750000  0.792453
# Logistic Regression                     0.785714  0.830189
# SVM                                     0.785714  0.862745
# Decision Tree                           0.750000  0.750000
# Random Forest                           0.750000  0.792453
# XGBoost                                 0.750000  0.792453
